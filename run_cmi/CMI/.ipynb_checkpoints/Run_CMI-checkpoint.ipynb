# %%
import pandas as pd
import os
import time

# กำหนดที่อยู่ของโฟลเดอร์หลัก
main_folder = r'P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, CMI\2022-2024\DATA CMI\RAW DATA'

# สร้างรายการเก็บข้อมูลจากไฟล์
dataframes = []

# วัดเวลาเริ่มต้น
start_time = time.time()

# วนลูปทุกโฟลเดอร์และไฟล์ในโฟลเดอร์หลัก
for root, dirs, files in os.walk(main_folder):
    for file_name in files:
        # ตรวจสอบนามสกุลของไฟล์
        if file_name.endswith(('.xlsx', '.xls', '.csv', '.ods')):
            # สร้างทางเข้าสำหรับไฟล์
            file_path = os.path.join(root, file_name)
            
            # ตรวจสอบนามสกุลของไฟล์
            if file_name.endswith(('.xlsx', '.xls')):
                # ใช้ ExcelFile ในการอ่านข้อมูลจาก Excel ที่มีหลาย sheet
                xls = pd.ExcelFile(file_path)
                for sheet_name in xls.sheet_names:
                    df = pd.read_excel(xls, sheet_name)
                    # เพิ่มคอลัมน์ 'Source' เพื่อระบุที่มาของข้อมูล
                    df['Source'] = os.path.join(root, file_name)
                    dataframes.append(df)
            elif file_name.endswith('.csv'):
                df = pd.read_csv(file_path)
                # เพิ่มคอลัมน์ 'Source' เพื่อระบุที่มาของข้อมูล
                df['Source'] = os.path.join(root, file_name)
                dataframes.append(df)
            elif file_name.endswith('.ods'):
                df = pd.read_excel(file_path, engine='odf')
                # เพิ่มคอลัมน์ 'Source' เพื่อระบุที่มาของข้อมูล
                df['Source'] = os.path.join(root, file_name)
                dataframes.append(df)

# วัดเวลาสิ้นสุด
elapsed_time = time.time() - start_time

# ต่อข้อมูลจาก DataFrame ทั้งหมด
merged_data = pd.concat(dataframes, ignore_index=True)

# แสดงผลลัพธ์
print("Merged Data:")
print(merged_data)

# แสดงเวลาที่ใช้
print("\nElapsed Time:", elapsed_time, "seconds")
# Out:
# Merged Data:
#         HCODE             AN            HN     DATEADM TIMEADM     DATEDSC  \
# 0        40.0  I40-24-006908  40-24-062963  29/11/2024   23:52  30/11/2024
# 1        40.0  I40-24-006887  40-24-033947  28/11/2024   17:49  29/11/2024
# 2        40.0  I40-24-006815  40-24-062348  24/11/2024   23:01  25/11/2024
# 3        40.0  I40-24-006600  40-24-007795  15/11/2024   15:09  16/11/2024
# 4        40.0  I40-24-006609  40-24-060401  15/11/2024   22:13  16/11/2024
# ...       ...            ...           ...         ...     ...         ...
# 120733   39.0  I39-25-003317  39-23-001507  29-04-2025   21:00  30-04-2025
# 120734   39.0  I39-25-003320  39-25-004686  29-04-2025   22:30  30-04-2025
# 120735    NaN            NaN           NaN         NaN     NaN         NaN
# 120736    NaN            NaN           NaN         NaN     NaN         NaN
# 120737    NaN            NaN           NaN         NaN     NaN         NaN
#
#        TIMEDSC  CALLOS  LEAVEDAY  ACTLOS  ... Unnamed: 2  D/C Unnamed: 215  \
# 0        01:12     0.0       0.0     0.0  ...        NaN  NaN          NaN
# 1        09:02     1.0       0.0     1.0  ...        NaN  NaN          NaN
# 2        12:54     1.0       0.0     1.0  ...        NaN  NaN          NaN
# 3        08:47     1.0       0.0     1.0  ...        NaN  NaN          NaN
# 4        08:35     1.0       0.0     1.0  ...        NaN  NaN          NaN
# ...        ...     ...       ...     ...  ...        ...  ...          ...
# 120733   18:51     1.0       0.0     1.0  ...        NaN  NaN          NaN
# 120734   17:53     1.0       0.0     1.0  ...        NaN  NaN          NaN
# 120735     NaN     NaN       NaN     NaN  ...        NaN  NaN          NaN
# 120736     NaN     NaN       NaN     NaN  ...        NaN  NaN          NaN
# 120737     NaN     NaN       NaN     NaN  ...        NaN  NaN          NaN
#
#         Unnamed: 3  Unnamed: 4  39-19-010503 30/08/2019  11:09  31/08/2019  \
# 0              NaN         NaN           NaN        NaN    NaN         NaN
# 1              NaN         NaN           NaN        NaN    NaN         NaN
# 2              NaN         NaN           NaN        NaN    NaN         NaN
# 3              NaN         NaN           NaN        NaN    NaN         NaN
# 4              NaN         NaN           NaN        NaN    NaN         NaN
# ...            ...         ...           ...        ...    ...         ...
# 120733         NaN         NaN           NaN        NaN    NaN         NaN
# 120734         NaN         NaN           NaN        NaN    NaN         NaN
# 120735         NaN         NaN           NaN        NaN    NaN         NaN
# 120736         NaN         NaN           NaN        NaN    NaN         NaN
# 120737         NaN         NaN           NaN        NaN    NaN         NaN
#
#         12:06
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 120733    NaN
# 120734    NaN
# 120735    NaN
# 120736    NaN
# 120737    NaN
#
# [120738 rows x 234 columns]
#
# Elapsed Time: 77.32202672958374 seconds

# %%
merged_data = merged_data.dropna(subset=['HCODE'])

# %%
selected_columns_merged_data = merged_data[['HCODE', 'AN','HN','DATEADM','DATEDSC','ACTLOS','WARDDSC','DEPT','AGE','AGEDAY','SEX','DISCHT','ADMWT',
                                            'PDX', 'SDX1', 'SDX2', 'SDX3', 'SDX4', 'SDX5', 'SDX6', 'SDX7', 'SDX8', 'SDX9', 'SDX10', 'SDX11', 'SDX12',
                                              'PROC1', 'PROC2', 'PROC3', 'PROC4', 'PROC5', 'PROC6', 'PROC7', 'PROC8', 'PROC9', 'PROC10',
                                             'PROC11', 'PROC12', 'PROC13', 'PROC14', 'PROC15', 'PROC16', 'PROC17', 'PROC18', 'PROC19', 'PROC20',
                                            'MDC','DRG','RW','ADJRW','WTLOS','Source']]

# %%
# สร้างฟังก์ชันสำหรับการแปลงสูตร Excel
def cal_OR_NON_OR_DRG(value):
    if 0 <= int(value[3:5]) <= 49:
        return 'OR'
    elif 50 <= int(value[3:5]) <= 99:
        return 'NON OR'
    else:
        return 'N/A'

# สร้าง column ใหม่โดยใช้ apply
selected_columns_merged_data.loc[:, 'OR TYPE'] = selected_columns_merged_data['DRG'].apply(cal_OR_NON_OR_DRG)
# Out:
# C:\Users\takdanai.sa\AppData\Local\Temp\ipykernel_19700\1693682378.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_columns_merged_data.loc[:, 'OR TYPE'] = selected_columns_merged_data['DRG'].apply(cal_OR_NON_OR_DRG)

# %%
selected_columns_merged_data
# Out:
#         HCODE             AN            HN     DATEADM     DATEDSC  ACTLOS  \
# 0        40.0  I40-24-006908  40-24-062963  29/11/2024  30/11/2024     0.0
# 1        40.0  I40-24-006887  40-24-033947  28/11/2024  29/11/2024     1.0
# 2        40.0  I40-24-006815  40-24-062348  24/11/2024  25/11/2024     1.0
# 3        40.0  I40-24-006600  40-24-007795  15/11/2024  16/11/2024     1.0
# 4        40.0  I40-24-006609  40-24-060401  15/11/2024  16/11/2024     1.0
# ...       ...            ...           ...         ...         ...     ...
# 120730   39.0  I39-25-003302  39-16-009515  29-04-2025  30-04-2025     1.0
# 120731   39.0  I39-25-003305  39-21-018659  29-04-2025  30-04-2025     1.0
# 120732   39.0  I39-25-003311  39-19-014697  29-04-2025  30-04-2025     1.0
# 120733   39.0  I39-25-003317  39-23-001507  29-04-2025  30-04-2025     1.0
# 120734   39.0  I39-25-003320  39-25-004686  29-04-2025  30-04-2025     1.0
#
#        WARDDSC    DEPT   AGE  AGEDAY  ...  PROC18  PROC19  PROC20  MDC  \
# 0          NaN  5006.0   0.0     0.0  ...     NaN     NaN     NaN  '15
# 1          NaN  5001.0   0.0     0.0  ...     NaN     NaN     NaN  '21
# 2          NaN  4081.0   0.0     0.0  ...     NaN     NaN     NaN  '21
# 3          NaN  5001.0   0.0     0.0  ...     NaN     NaN     NaN  '21
# 4          NaN  4080.0   0.0     0.0  ...     NaN     NaN     NaN  '21
# ...        ...     ...   ...     ...  ...     ...     ...     ...  ...
# 120730    39W9  4086.0  50.0     NaN  ...     NaN     NaN     NaN  '03
# 120731    39W8  4085.0   3.0     NaN  ...     NaN     NaN     NaN  '18
# 120732    39W3  4080.0  35.0     NaN  ...     NaN     NaN     NaN  '06
# 120733    39W3  4080.0  48.0     NaN  ...     NaN     NaN     NaN  '03
# 120734    39W7  4084.0   8.0     NaN  ...     NaN     NaN     NaN  '03
#
#            DRG           RW   ADJRW WTLOS  \
# 0       '15500       0.1878  0.1878  1.14
# 1       '21530       0.1899  0.1899  1.42
# 2       '21520       0.1955  0.1955  1.27
# 3       '21520       0.1955  0.1955  1.27
# 4       '21520       0.1955  0.1955  1.27
# ...        ...          ...     ...   ...
# 120730  '03510  0.241300002  0.2413  1.77
# 120731  '18610  0.285100013  0.2851  2.47
# 120732  '06640  0.268599987  0.2686  1.82
# 120733  '03521  0.590699971  0.5375  3.22
# 120734  '03520   0.32280001  0.3228  2.48
#
#                                                    Source OR TYPE
# 0       P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# 1       P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# 2       P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# 3       P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# 4       P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# ...                                                   ...     ...
# 120730  P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# 120731  P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# 120732  P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# 120733  P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# 120734  P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
#
# [119996 rows x 53 columns]

# %%
# ฟังก์ชันสำหรับการแปลงวันที่
def convert_date_format(date_str):
    try:
        return pd.to_datetime(date_str, format='%d-%m-%Y')
    except ValueError:
        return pd.to_datetime(date_str, format='%d/%m/%Y', errors='coerce')

selected_columns_merged_data['DATEADM'] = selected_columns_merged_data['DATEADM'].apply(convert_date_format)
selected_columns_merged_data['DATEDSC'] = selected_columns_merged_data['DATEDSC'].apply(convert_date_format)
# Out:
# C:\Users\takdanai.sa\AppData\Local\Temp\ipykernel_19700\4121723930.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_columns_merged_data['DATEADM'] = selected_columns_merged_data['DATEADM'].apply(convert_date_format)
# C:\Users\takdanai.sa\AppData\Local\Temp\ipykernel_19700\4121723930.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_columns_merged_data['DATEDSC'] = selected_columns_merged_data['DATEDSC'].apply(convert_date_format)

# %%
selected_columns_merged_data
# Out:
#         HCODE             AN            HN    DATEADM    DATEDSC  ACTLOS  \
# 0        40.0  I40-24-006908  40-24-062963 2024-11-29 2024-11-30     0.0
# 1        40.0  I40-24-006887  40-24-033947 2024-11-28 2024-11-29     1.0
# 2        40.0  I40-24-006815  40-24-062348 2024-11-24 2024-11-25     1.0
# 3        40.0  I40-24-006600  40-24-007795 2024-11-15 2024-11-16     1.0
# 4        40.0  I40-24-006609  40-24-060401 2024-11-15 2024-11-16     1.0
# ...       ...            ...           ...        ...        ...     ...
# 120730   39.0  I39-25-003302  39-16-009515 2025-04-29 2025-04-30     1.0
# 120731   39.0  I39-25-003305  39-21-018659 2025-04-29 2025-04-30     1.0
# 120732   39.0  I39-25-003311  39-19-014697 2025-04-29 2025-04-30     1.0
# 120733   39.0  I39-25-003317  39-23-001507 2025-04-29 2025-04-30     1.0
# 120734   39.0  I39-25-003320  39-25-004686 2025-04-29 2025-04-30     1.0
#
#        WARDDSC    DEPT   AGE  AGEDAY  ...  PROC18  PROC19  PROC20  MDC  \
# 0          NaN  5006.0   0.0     0.0  ...     NaN     NaN     NaN  '15
# 1          NaN  5001.0   0.0     0.0  ...     NaN     NaN     NaN  '21
# 2          NaN  4081.0   0.0     0.0  ...     NaN     NaN     NaN  '21
# 3          NaN  5001.0   0.0     0.0  ...     NaN     NaN     NaN  '21
# 4          NaN  4080.0   0.0     0.0  ...     NaN     NaN     NaN  '21
# ...        ...     ...   ...     ...  ...     ...     ...     ...  ...
# 120730    39W9  4086.0  50.0     NaN  ...     NaN     NaN     NaN  '03
# 120731    39W8  4085.0   3.0     NaN  ...     NaN     NaN     NaN  '18
# 120732    39W3  4080.0  35.0     NaN  ...     NaN     NaN     NaN  '06
# 120733    39W3  4080.0  48.0     NaN  ...     NaN     NaN     NaN  '03
# 120734    39W7  4084.0   8.0     NaN  ...     NaN     NaN     NaN  '03
#
#            DRG           RW   ADJRW WTLOS  \
# 0       '15500       0.1878  0.1878  1.14
# 1       '21530       0.1899  0.1899  1.42
# 2       '21520       0.1955  0.1955  1.27
# 3       '21520       0.1955  0.1955  1.27
# 4       '21520       0.1955  0.1955  1.27
# ...        ...          ...     ...   ...
# 120730  '03510  0.241300002  0.2413  1.77
# 120731  '18610  0.285100013  0.2851  2.47
# 120732  '06640  0.268599987  0.2686  1.82
# 120733  '03521  0.590699971  0.5375  3.22
# 120734  '03520   0.32280001  0.3228  2.48
#
#                                                    Source OR TYPE
# 0       P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# 1       P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# 2       P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# 3       P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# 4       P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# ...                                                   ...     ...
# 120730  P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# 120731  P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# 120732  P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# 120733  P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# 120734  P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
#
# [119996 rows x 53 columns]

# %%
def replace_icd_10(df, columns):
    for col in columns:
        # ตรวจสอบและจัดการค่า NaN ในคอลัมน์
        df[col].fillna('', inplace=True)

        # แปลงค่าในคอลัมน์
        df[col] = df[col].str.strip("'").apply(lambda x: x[:3] + ('.' + x[3:] if len(x) > 3 else ''))

    return df

# %%
# เรียกใช้งานฟังก์ชัน
columns_to_process = ['PDX', 'SDX1', 'SDX2', 'SDX3', 'SDX4', 'SDX5', 'SDX6', 'SDX7', 'SDX8', 'SDX9', 'SDX10', 'SDX11', 'SDX12']
selected_columns_merged_data = replace_icd_10(selected_columns_merged_data, columns_to_process)
# Out:
# C:\Users\takdanai.sa\AppData\Local\Temp\ipykernel_19700\3566952706.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].fillna('', inplace=True)
# C:\Users\takdanai.sa\AppData\Local\Temp\ipykernel_19700\3566952706.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].str.strip("'").apply(lambda x: x[:3] + ('.' + x[3:] if len(x) > 3 else ''))

# %%
def replace_icd_9(df, columns):
    for col in columns:
        # ตรวจสอบและจัดการค่า NaN ในคอลัมน์
        df[col].fillna('', inplace=True)

         # แปลงค่าในคอลัมน์
        df[col] = df[col].str.strip("'")

    return df

# %%
# เรียกใช้งานฟังก์ชัน
columns_to_process = ['PROC1', 'PROC2', 'PROC3', 'PROC4', 'PROC5', 'PROC6', 'PROC7', 'PROC8', 'PROC9', 'PROC10',
                     'PROC11', 'PROC12', 'PROC13', 'PROC14', 'PROC15', 'PROC16', 'PROC17', 'PROC18', 'PROC19', 'PROC20']
selected_columns_merged_data = replace_icd_9(selected_columns_merged_data, columns_to_process)
# Out:
# C:\Users\takdanai.sa\AppData\Local\Temp\ipykernel_19700\237973253.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].fillna('', inplace=True)

# %%
def replace_symbol(df, columns):
    for col in columns:
        # ตรวจสอบและจัดการค่า NaN ในคอลัมน์
        df[col].fillna('', inplace=True)

        # แปลงค่าในคอลัมน์
        df[col] = df[col].str.strip("'")

    return df

# %%
# เรียกใช้งานฟังก์ชัน
columns_to_process = ['MDC', 'DRG']
selected_columns_merged_data = replace_symbol(selected_columns_merged_data, columns_to_process)
# Out:
# C:\Users\takdanai.sa\AppData\Local\Temp\ipykernel_19700\826058740.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].fillna('', inplace=True)
# C:\Users\takdanai.sa\AppData\Local\Temp\ipykernel_19700\826058740.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].str.strip("'")

# %%
selected_columns_merged_data
# Out:
#         HCODE             AN            HN    DATEADM    DATEDSC  ACTLOS  \
# 0        40.0  I40-24-006908  40-24-062963 2024-11-29 2024-11-30     0.0
# 1        40.0  I40-24-006887  40-24-033947 2024-11-28 2024-11-29     1.0
# 2        40.0  I40-24-006815  40-24-062348 2024-11-24 2024-11-25     1.0
# 3        40.0  I40-24-006600  40-24-007795 2024-11-15 2024-11-16     1.0
# 4        40.0  I40-24-006609  40-24-060401 2024-11-15 2024-11-16     1.0
# ...       ...            ...           ...        ...        ...     ...
# 120730   39.0  I39-25-003302  39-16-009515 2025-04-29 2025-04-30     1.0
# 120731   39.0  I39-25-003305  39-21-018659 2025-04-29 2025-04-30     1.0
# 120732   39.0  I39-25-003311  39-19-014697 2025-04-29 2025-04-30     1.0
# 120733   39.0  I39-25-003317  39-23-001507 2025-04-29 2025-04-30     1.0
# 120734   39.0  I39-25-003320  39-25-004686 2025-04-29 2025-04-30     1.0
#
#        WARDDSC    DEPT   AGE  AGEDAY  ...  PROC18  PROC19  PROC20 MDC    DRG  \
# 0          NaN  5006.0   0.0     0.0  ...                          15  15500
# 1          NaN  5001.0   0.0     0.0  ...                          21  21530
# 2          NaN  4081.0   0.0     0.0  ...                          21  21520
# 3          NaN  5001.0   0.0     0.0  ...                          21  21520
# 4          NaN  4080.0   0.0     0.0  ...                          21  21520
# ...        ...     ...   ...     ...  ...     ...     ...     ...  ..    ...
# 120730    39W9  4086.0  50.0     NaN  ...                          03  03510
# 120731    39W8  4085.0   3.0     NaN  ...                          18  18610
# 120732    39W3  4080.0  35.0     NaN  ...                          06  06640
# 120733    39W3  4080.0  48.0     NaN  ...                          03  03521
# 120734    39W7  4084.0   8.0     NaN  ...                          03  03520
#
#                  RW   ADJRW WTLOS  \
# 0            0.1878  0.1878  1.14
# 1            0.1899  0.1899  1.42
# 2            0.1955  0.1955  1.27
# 3            0.1955  0.1955  1.27
# 4            0.1955  0.1955  1.27
# ...             ...     ...   ...
# 120730  0.241300002  0.2413  1.77
# 120731  0.285100013  0.2851  2.47
# 120732  0.268599987  0.2686  1.82
# 120733  0.590699971  0.5375  3.22
# 120734   0.32280001  0.3228  2.48
#
#                                                    Source OR TYPE
# 0       P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# 1       P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# 2       P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# 3       P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# 4       P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# ...                                                   ...     ...
# 120730  P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# 120731  P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# 120732  P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# 120733  P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
# 120734  P:\Support Data\ICD-CMI, OR, COVID, Dead\ICD, ...  NON OR
#
# [119996 rows x 53 columns]

# %%
selected_columns_merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 119996 entries, 0 to 120734
# Data columns (total 53 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   HCODE    119996 non-null  float64
#  1   AN       119996 non-null  object
#  2   HN       119996 non-null  object
#  3   DATEADM  119996 non-null  datetime64[ns]
#  4   DATEDSC  119996 non-null  datetime64[ns]
#  5   ACTLOS   119996 non-null  float64
#  6   WARDDSC  108907 non-null  object
#  7   DEPT     119995 non-null  float64
#  8   AGE      113978 non-null  float64
#  9   AGEDAY   17107 non-null   float64
#  10  SEX      119976 non-null  float64
#  11  DISCHT   119978 non-null  float64
#  12  ADMWT    39329 non-null   float64
#  13  PDX      119996 non-null  object
#  14  SDX1     119996 non-null  object
#  15  SDX2     119996 non-null  object
#  16  SDX3     119996 non-null  object
#  17  SDX4     119996 non-null  object
#  18  SDX5     119996 non-null  object
#  19  SDX6     119996 non-null  object
#  20  SDX7     119996 non-null  object
#  21  SDX8     119996 non-null  object
#  22  SDX9     119996 non-null  object
#  23  SDX10    119996 non-null  object
#  24  SDX11    119996 non-null  object
#  25  SDX12    119996 non-null  object
#  26  PROC1    119996 non-null  object
#  27  PROC2    119996 non-null  object
#  28  PROC3    119996 non-null  object
#  29  PROC4    119996 non-null  object
#  30  PROC5    119996 non-null  object
#  31  PROC6    119996 non-null  object
#  32  PROC7    119996 non-null  object
#  33  PROC8    119996 non-null  object
#  34  PROC9    119996 non-null  object
#  35  PROC10   119996 non-null  object
#  36  PROC11   119996 non-null  object
#  37  PROC12   119996 non-null  object
#  38  PROC13   119996 non-null  object
#  39  PROC14   119996 non-null  object
#  40  PROC15   119996 non-null  object
#  41  PROC16   119996 non-null  object
#  42  PROC17   119996 non-null  object
#  43  PROC18   119996 non-null  object
#  44  PROC19   119996 non-null  object
#  45  PROC20   119996 non-null  object
#  46  MDC      119996 non-null  object
#  47  DRG      119996 non-null  object
#  48  RW       119996 non-null  object
#  49  ADJRW    119996 non-null  float64
#  50  WTLOS    119996 non-null  float64
#  51  Source   119996 non-null  object
#  52  OR TYPE  119996 non-null  object
# dtypes: datetime64[ns](2), float64(10), object(41)
# memory usage: 49.4+ MB

# %%
selected_columns_merged_data_no_duplicates = selected_columns_merged_data.drop_duplicates(subset='AN')

# %%
selected_columns_merged_data_no_duplicates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 115308 entries, 0 to 120734
# Data columns (total 53 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   HCODE    115308 non-null  float64
#  1   AN       115308 non-null  object
#  2   HN       115308 non-null  object
#  3   DATEADM  115308 non-null  datetime64[ns]
#  4   DATEDSC  115308 non-null  datetime64[ns]
#  5   ACTLOS   115308 non-null  float64
#  6   WARDDSC  104308 non-null  object
#  7   DEPT     115307 non-null  float64
#  8   AGE      109496 non-null  float64
#  9   AGEDAY   16812 non-null   float64
#  10  SEX      115288 non-null  float64
#  11  DISCHT   115292 non-null  float64
#  12  ADMWT    38377 non-null   float64
#  13  PDX      115308 non-null  object
#  14  SDX1     115308 non-null  object
#  15  SDX2     115308 non-null  object
#  16  SDX3     115308 non-null  object
#  17  SDX4     115308 non-null  object
#  18  SDX5     115308 non-null  object
#  19  SDX6     115308 non-null  object
#  20  SDX7     115308 non-null  object
#  21  SDX8     115308 non-null  object
#  22  SDX9     115308 non-null  object
#  23  SDX10    115308 non-null  object
#  24  SDX11    115308 non-null  object
#  25  SDX12    115308 non-null  object
#  26  PROC1    115308 non-null  object
#  27  PROC2    115308 non-null  object
#  28  PROC3    115308 non-null  object
#  29  PROC4    115308 non-null  object
#  30  PROC5    115308 non-null  object
#  31  PROC6    115308 non-null  object
#  32  PROC7    115308 non-null  object
#  33  PROC8    115308 non-null  object
#  34  PROC9    115308 non-null  object
#  35  PROC10   115308 non-null  object
#  36  PROC11   115308 non-null  object
#  37  PROC12   115308 non-null  object
#  38  PROC13   115308 non-null  object
#  39  PROC14   115308 non-null  object
#  40  PROC15   115308 non-null  object
#  41  PROC16   115308 non-null  object
#  42  PROC17   115308 non-null  object
#  43  PROC18   115308 non-null  object
#  44  PROC19   115308 non-null  object
#  45  PROC20   115308 non-null  object
#  46  MDC      115308 non-null  object
#  47  DRG      115308 non-null  object
#  48  RW       115308 non-null  object
#  49  ADJRW    115308 non-null  float64
#  50  WTLOS    115308 non-null  float64
#  51  Source   115308 non-null  object
#  52  OR TYPE  115308 non-null  object
# dtypes: datetime64[ns](2), float64(10), object(41)
# memory usage: 47.5+ MB

# %%
import time

excel_file_path = 'RAW_CMI.xlsx'  # ระบุ path และชื่อไฟล์ Excel ที่คุณต้องการ

# บันทึกเวลาเริ่มต้น
start_time = time.time()

# Export DataFrame เป็นไฟล์ Excel ด้วย Pandas
selected_columns_merged_data.to_excel(excel_file_path, index=False)

# คำนวณและแสดงเวลาที่ใช้
elapsed_time = time.time() - start_time
print(f'เวลาที่ใช้ในการ export เป็นไฟล์ Excel: {elapsed_time:.2f} วินาที')
# Out:
# เวลาที่ใช้ในการ export เป็นไฟล์ Excel: 93.38 วินาที
